# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix,classification_report

# %%
df = pd.read_csv("/content/voice_capstone_dataset.csv")
df
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
#              kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0      274.402905  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1      634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2     1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3        4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4        4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
# ...           ...       ...       ...  ...       ...       ...       ...
# 3163     6.630383  0.962934  0.763182  ...  0.131884  0.182790  0.083770
# 3164     2.503954  0.960716  0.709570  ...  0.116221  0.188980  0.034409
# 3165     6.604509  0.946854  0.654196  ...  0.142056  0.209918  0.039506
# 3166     5.388298  0.950436  0.675470  ...  0.143659  0.172375  0.034483
# 3167     5.769115  0.938829  0.601529  ...  0.165509  0.185607  0.062257
#
#         maxfun   meandom    mindom    maxdom   dfrange   modindx   label
# 0     0.275862  0.007812  0.007812  0.007812  0.000000  0.000000    male
# 1     0.250000  0.009014  0.007812  0.054688  0.046875  0.052632    male
# 2     0.271186  0.007990  0.007812  0.015625  0.007812  0.046512    male
# 3     0.250000  0.201497  0.007812  0.562500  0.554688  0.247119    male
# 4     0.266667  0.712812  0.007812  5.484375  5.476562  0.208274    male
# ...        ...       ...       ...       ...       ...       ...     ...
# 3163  0.262295  0.832899  0.007812  4.210938  4.203125  0.161929  female
# 3164  0.275862  0.909856  0.039062  3.679688  3.640625  0.277897  female
# 3165  0.275862  0.494271  0.007812  2.937500  2.929688  0.194759  female
# 3166  0.250000  0.791360  0.007812  3.593750  3.585938  0.311002  female
# 3167  0.271186  0.227022  0.007812  0.554688  0.546875  0.350000  female
#
# [3168 rows x 21 columns]

# %%
for column in df.columns:
    sns.kdeplot(df[column])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-c3a139faad04> in <cell line: 1>()
#       1 for column in df.columns:
# ----> 2     sns.kdeplot(df[column])
#       3     plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1693         ax = plt.gca()
#    1694
# -> 1695     p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1696
#    1697     method = ax.fill_between if fill else ax.plot
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in _attach(self, obj, allowed_types, log_scale)
#    1209                     f"{allowed_types} is required"
#    1210                 )
# -> 1211                 raise TypeError(err)
#    1212
#    1213         # -- Get axis objects for each row in plot_data for type conversions and scaling
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %%
for column in df.columns:
    plt.hist(df[column])
    plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,cmap='mako')
plt.show()
# Out:
# <ipython-input-19-21b6fb624207>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='mako')

# %%
df['label'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
for column in df.columns:
    plt.scatter(y=column,x='label',data=df)
    plt.show()

# %%
label_encoder=LabelEncoder()
df['label']=label_encoder.fit_transform(df['label'])

# %%
dict(enumerate(label_encoder.classes_))
# Out:
# {0: 'female', 1: 'male'}

# %%
def preprocess_inputs(df):
    df=df.copy()
    #splitting between feature and target
    y=df['label']
    x=df.drop('label',axis=1)
    #scaling the dataset
    #train_test_split
    x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)
    scaler=StandardScaler()
    scaler.fit(x_train)
    x_train=pd.DataFrame(scaler.transform(x_train),columns=x_train.columns)
    x_test=pd.DataFrame(scaler.transform(x_test),columns=x_test.columns)
    
    
    
    return x_train,x_test,y_train,y_test

# %%
x_train,x_test,y_train,y_test=preprocess_inputs(df)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2217, 20)
# (951, 20)
# (2217,)
# (951,)

# %%
y_test
# Out:
# 2130    0
# 2351    0
# 2855    0
# 3015    0
# 2240    0
#        ..
# 119     1
# 1332    1
# 3135    0
# 2643    0
# 1142    1
# Name: label, Length: 951, dtype: int64

# %%
input=tf.keras.Input(shape=(20,))
x=tf.keras.layers.Dense(64,activation='relu')(input)
x=tf.keras.layers.Dense(64,activation='relu')(x)
output=tf.keras.layers.Dense(1,activation='sigmoid')(x)
model=tf.keras.Model(inputs=input,outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20)]              0
#
#  dense (Dense)               (None, 64)                1344
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5,569
# Trainable params: 5,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy',tf.keras.metrics.AUC(name='auc')])
history=model.fit(x_train,y_train,validation_split=0.2,batch_size=32,epochs=100,
                 callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=3,
                                                            restore_best_weights=True)])
# Out:
# Epoch 1/100
# 56/56 [==============================] - 2s 8ms/step - loss: 9.8842e-04 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9752 - val_auc: 0.9831
# Epoch 2/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.9730 - val_auc: 0.9834
# Epoch 3/100
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9989 - auc: 0.9994 - val_loss: 0.2219 - val_accuracy: 0.9685 - val_auc: 0.9829
# Epoch 4/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9994 - auc: 1.0000 - val_loss: 0.2492 - val_accuracy: 0.9730 - val_auc: 0.9809

# %%
y_pred=np.squeeze(model.predict(x_test))
# Out:
# 30/30 [==============================] - 0s 1ms/step

# %%
model.evaluate(x_test,y_test)
# Out:
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1667 - accuracy: 0.9769 - auc: 0.9866
# [0.16666419804096222, 0.9768664836883545, 0.9865698218345642]

# %%
threshold = 0.5
y_pred = (y_pred >= threshold).astype(int)

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,cmap='mako')
plt.show()

# %%
clr=classification_report(y_test,y_pred)
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       482
#            1       0.98      0.97      0.98       469
#
#     accuracy                           0.98       951
#    macro avg       0.98      0.98      0.98       951
# weighted avg       0.98      0.98      0.98       951
